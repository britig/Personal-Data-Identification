# %% [markdown]
# # Prediction Using Trained Model

# %%
from keras.models import model_from_json
from keras.preprocessing import image
import os
import shutil

def move(src,dest):
    shutil.move(src,dest)

# dimensions of our images.
img_width, img_height = 150, 150


input_shape = (img_width, img_height, 3)
 
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("new_weight.h5")

im_name = os.listdir('C:/Users/IBM_ADMIN/Downloads/samplecard/ssn_images/only_cards_images')

for item in im_name: 
    # predicting images
    img = image.load_img('C:/Users/IBM_ADMIN/Downloads/samplecard/ssn_images/images/'+item, target_size=(img_width, img_height))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)

    images = np.vstack([x])
    classes = loaded_model.predict_classes(images, batch_size=10)
    f=open(item, "w")
    if classes[0][0]==0:
        move('C:/Users/IBM_ADMIN/Downloads/samplecard/ssn_images/images/'+item,'C:/Users/IBM_ADMIN/Desktop/credit card/'+item)
        print(item+' is credit-card')
    else:
        move('C:/Users/IBM_ADMIN/Downloads/samplecard/ssn_images/images/'+item,'C:/Users/IBM_ADMIN/Desktop/non pi/'+item)
        print(item+' is not a credit card')
# Out:
# 001-06-1821.jpeg is credit-card
# 001-33-7381.jpeg is not a credit card
# 001-67-9735.jpeg is not a credit card
# 002-04-4045.jpeg is not a credit card
# 002-35-3044.jpeg is not a credit card
# 002-57-4578.jpeg is not a credit card
# 002-58-0226.jpeg is not a credit card
# 002-69-0488.jpeg is not a credit card
# 002-72-1903.jpeg is not a credit card
# 002-91-0242.jpeg is not a credit card
# 003-07-6564.jpeg is not a credit card
# 003-16-2275.jpeg is credit-card
# 003-26-8016.jpeg is not a credit card
# 003-47-0392.jpeg is not a credit card
# 003-69-0514.jpeg is not a credit card
# 003-72-2500.jpeg is not a credit card
# 003-82-0377.jpeg is not a credit card
# 004-58-3534.jpeg is not a credit card
# 004-59-6601.jpeg is not a credit card
# 004-60-3850.jpeg is not a credit card
# 004-72-1843.jpeg is not a credit card
# 004-83-7816.jpeg is not a credit card
# 004-92-1981.jpeg is not a credit card
# 004-92-9610.jpeg is not a credit card
# 005-18-8238.jpeg is not a credit card
# ...

# %%
from keras.utils import plot_model
from keras.models import model_from_json

# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

plot_model(loaded_model, to_file='model.png')
# Out:
# C:\Users\IBM_ADMIN\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
plot_model(loaded_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

datagen = ImageDataGenerator(
        rotation_range=40,
        horizontal_flip=True)

img = load_img('C:/Users/IBM_ADMIN/Desktop/image/samplecard/temp-2.jpg')  # this is a PIL image
x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)

# the .flow() command below generates batches of randomly transformed images
# and saves the results to the `preview/` directory
i = 0
for batch in datagen.flow(x, batch_size=1,
                          save_to_dir='preview', save_prefix='cards', save_format='jpeg'):
    i += 1
    if i > 20:
        break  # otherwise the generator would loop indefinitely

# %%
print(loaded_model)
